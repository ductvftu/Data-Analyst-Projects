# %% [markdown]
# <h1 align="center">Act Report</h1>
# <h2 align="center">Insight into final dataset of We Rate Dogs</h2>

# %% [markdown]
# ## Introduction
#
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. WeRateDogs has over 4 million followers and has received international media coverage. Dogs are rating on the scale of 1 to 10, however, there are case when the rating exceed 10, such as 11/10, 12/10. This is a unique feature of their rating system which act like a humour factor. As the dataset provide informations focus on the tweets (likes, retweets) and some classification and details of the dog mentioned (dog breed, name ...), my main interest was focus on 3 main questions:
# - What is the most popular dog breed
# - What is their average rating
# - How have the trend for dog rating change overtime
#
# ### Insight #1: What is the most popular dog breed:

# %%
from IPython.display import Image
image_path = 'Result_1.png'
# Display the image
Image(filename=image_path)

# %% [markdown]
# The graph above state the name of the 10 most popular dog breed. The metric to measure the popularity i used here was based on the counts of tweets about the specific dog breed. And it seems like Golden Retriever was the most famous among them, being mentioned 146 times, much higher than the second place (Labrador retriever with 97 times)
#
# ### Insight #2: What is the average rating of these popular dog breed:

# %%
image_path = 'Result_2.png'
# Display the image
Image(filename=image_path)

# %% [markdown]
# I wanted to measure the top 10 highest rating among all the breed, however there case where the breed was only mentioned 1 and receive ridiculious rating so it became inacurate to analyze, therefore i chose to measure the popularity of the most popular dog, given that they are mentioned many time so the rating will be more appropriate. Among the most popular dog, it seems like Samoyed received the highest rating, at an average of 11.7 while pug was the least favourite with a point of 10.24
#
# ### Insight #3: What is the average rating of these popular dog breed:

# %%
image_path = 'Result_3.png'
# Display the image
Image(filename=image_path)

# %% [markdown]
# The graph was constructed on a monthly basis. It can be seen from the graph that the postings regard the dog trends spiked up in early time of the period, at more then 300 posts in January 2016, however, the amounts of posts decreased dramatically overtime to only more than 100 posts after 3 months. This slowly decrease overtime and barely get any interaction near the time of October 2017.
